# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
#lê a base

url = 'https://raw.githubusercontent.com/thalyssa/MachineLearningClasses/main/Market_Basket_Optimisation.csv'
store_data = pd.read_csv(url)
store_data.head()
# Out:
#            shrimp    almonds     avocado  ... frozen smoothie spinach olive oil
# 0         burgers  meatballs        eggs  ...             NaN     NaN       NaN
# 1         chutney        NaN         NaN  ...             NaN     NaN       NaN
# 2          turkey    avocado         NaN  ...             NaN     NaN       NaN
# 3   mineral water       milk  energy bar  ...             NaN     NaN       NaN
# 4  low fat yogurt        NaN         NaN  ...             NaN     NaN       NaN
#
# [5 rows x 20 columns]

# %%
#transforma o dataframe em lista para se trabalhar com as bibliotecas
store_list = store_data.values.tolist()
transactions_array = np.array(store_list)

#encoda a lista para que se possa utilizar o algoritmo apriori
te = TransactionEncoder()
transactions_data = te.fit_transform(transactions_array)
transactions_data = pd.DataFrame(transactions_data, columns=te.columns_)
transactions_data = transactions_data.replace(np.nan, False)
transactions_data.head(10)
# Out:
#     asparagus  almonds  antioxydant juice  ...   yams  yogurt cake  zucchini
# 0       False    False              False  ...  False        False     False
# 1       False    False              False  ...  False        False     False
# 2       False    False              False  ...  False        False     False
# 3       False    False              False  ...  False        False     False
# 4       False    False              False  ...  False        False     False
# 5       False    False              False  ...  False        False     False
# 6       False    False              False  ...  False        False     False
# 7       False    False              False  ...  False        False     False
# 8       False    False              False  ...  False        False     False
# 9       False    False              False  ...  False        False     False
#
# [10 rows x 121 columns]

# %%
#implementação do algoritmo apriori
frequent_itemsets = apriori(transactions_data, min_support=0.01, use_colnames=True)
frequent_itemsets['Length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#       support                                      itemsets  Length
# 0    0.020267                                     (almonds)       1
# 1    0.033200                                     (avocado)       1
# 2    0.010800                              (barbecue sauce)       1
# 3    0.014267                                   (black tea)       1
# 4    0.011467                                  (body spray)       1
# ..        ...                                           ...     ...
# 514  0.011067       (nan, mineral water, milk, ground beef)       4
# 515  0.017067  (nan, mineral water, spaghetti, ground beef)       4
# 516  0.015733         (nan, mineral water, spaghetti, milk)       4
# 517  0.010267    (nan, mineral water, spaghetti, olive oil)       4
# 518  0.011467     (nan, mineral water, spaghetti, pancakes)       4
#
# [519 rows x 3 columns]

# %%
#checa as regras encontradas
rules_df = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
rules_df["Antecedents_Length"] = rules_df["antecedents"].apply(lambda x: len(x))
rules_df["Consequents_Length"] = rules_df["consequents"].apply(lambda x: len(x))
rules_df.sort_values("lift",ascending=False)
# Out:
#               antecedents  ... Consequents_Length
# 642         (ground beef)  ...                  2
# 641  (nan, herb & pepper)  ...                  1
# 640    (ground beef, nan)  ...                  1
# 643       (herb & pepper)  ...                  2
# 160         (ground beef)  ...                  1
# ..                    ...  ...                ...
# 630              (shrimp)  ...                  2
# 154              (shrimp)  ...                  1
# 629      (nan, green tea)  ...                  1
# 155           (green tea)  ...                  1
# 631           (green tea)  ...                  2
#
# [1050 rows x 11 columns]

# %%
rules_df.sort_values("support",ascending=False)
# Out:
#                 antecedents  ... Consequents_Length
# 775        (nan, spaghetti)  ...                  1
# 219             (spaghetti)  ...                  1
# 218         (mineral water)  ...                  1
# 774    (nan, mineral water)  ...                  1
# 777             (spaghetti)  ...                  2
# ..                      ...  ...                ...
# 118     (frozen vegetables)  ...                  1
# 119       (frozen smoothie)  ...                  1
# 545  (nan, frozen smoothie)  ...                  1
# 546     (frozen vegetables)  ...                  2
# 547       (frozen smoothie)  ...                  2
#
# [1050 rows x 11 columns]
